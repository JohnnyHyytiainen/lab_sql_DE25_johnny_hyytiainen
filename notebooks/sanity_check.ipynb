# %% [markdown]
# # Sanity check to see if src/ingest_sakila_dlt.py works as intended.
#
# - Expected output:
#     - `path to where sakila.duckdb is` True
#     - Check if TABLES exist

# %%
# Kod: Engelska
# Kommentarer: Svenska
from pathlib import Path
import duckdb
import pandas as pd

# Paths
CWD = Path.cwd()
DB_PATH = CWD.parent / "db" / "sakila.duckdb"

# Connect to DuckDB
con = duckdb.connect(str(DB_PATH), read_only=True)  # Read only för säkerhet

print(f"Connected to: {DB_PATH}")
print(f"Available tables:")
con.sql("SHOW TABLES").df()
# Out:
# c:\Users\johnn\Desktop\labs\lab_sql_DE25_johnny_hyytiainen\db\sakila.duckdb True
# Empty DataFrame
# Columns: [name]
# Index: []
